# %%
import pandas as pd

# %%
course_dataframe = pd.read_json("../raw_course_data.json")

course_dataframe.dtypes

print(course_dataframe)

# df = course_dataframe.explode('provider_courses').reset_index()

# normalised_df = pd.json_normalize(df.provider_courses)

# concat_normalised_df = pd.concat([df, normalised_df], axis=1).drop(['provider_courses', 'provider_locations'], axis=1)

# concat_normalised_df

# def find_time_commitment(x):
#     if 'part time' in x.course_name.lower():
#         return 'part_time'
    
#     if 'full time' in x.course_name.lower():
#         return 'full_time'
    
#     else:
#         return None


# concat_normalised_df['time'] = concat_normalised_df.apply(lambda x: find_time_commitment(x), axis=1)
# Out:
#          provider_name                                 provider_locations
# 0          {Pro}Coders                                   [West Yorkshire]  \
# 1        Command Shift  [Birmingham, Bristol, Cambridge, Dublin, Edinb...
# 2       Codez Academy                                             [Wales]
# 3       School of Code        [Birmingham, Liverpool, London, Manchester]
# 4           Coders Lab  [Amsterdam, Brussels, Bucharest, Edinburgh, Gl...
# 5               Nology  [Bristol, London, Manchester, Melbourne, Onlin...
# 6                 EyUp                                        [Sheffield]
# 7          Coder Space                                        [Liverpool]
# 8       Makers Academy   [Bristol, Cambridge, London, Manchester, Online]
# 9          Code Nation                            [Cambridge, Manchester]
# 10  Shillington School  [Brisbane, London, Manchester, Melbourne, New ...
# 11            CodeClan                               [Edinburgh, Glasgow]
# ...

# %%
df = course_dataframe.explode('provider_courses').reset_index()

df[df['provider_courses'].apply(lambda x: isinstance(x, str))]



normalised_df = pd.json_normalize(df.provider_courses)

normalised_df = pd.concat([df, normalised_df], axis=1)

normalised_df
# Out:
#     index   provider_name                                 provider_locations
# 0       0     {Pro}Coders                                   [West Yorkshire]  \
# 1       1   Command Shift  [Birmingham, Bristol, Cambridge, Dublin, Edinb...
# 2       2  Codez Academy                                             [Wales]
# 3       2  Codez Academy                                             [Wales]
# 4       3  School of Code        [Birmingham, Liverpool, London, Manchester]
# ..    ...             ...                                                ...
# 95     27        Ironhack  [Amsterdam, Barcelona, Berlin, Bordeaux, Düsse...
# 96     27        Ironhack  [Amsterdam, Barcelona, Berlin, Bordeaux, Düsse...
# 97     27        Ironhack  [Amsterdam, Barcelona, Berlin, Bordeaux, Düsse...
# 98     28  23 Code Street                                           [London]
# 99     29      TechSwitch                                           [London]
#
# ...

# %%
exploded_locations = concat_normalised_df.explode('course_skills').reset_index().drop(['index', 'level_0'], axis=1)

normalised_meta = pd.concat([exploded_locations, pd.json_normalize(exploded_locations.meta)], axis=1).drop('meta', axis=1)

exploded_tracks = normalised_meta.explode('provider_tracks').reset_index().drop(['index'], axis=1)

exploded_tracks
# Out:
#      provider_name       provider_tracks                 course_name
# 0      {Pro}Coders  Full Stack Developer  Full-Stack Web Development  \
# 1      {Pro}Coders  Full Stack Developer  Full-Stack Web Development
# 2      {Pro}Coders  Full Stack Developer  Full-Stack Web Development
# 3      {Pro}Coders  Full Stack Developer  Full-Stack Web Development
# 4      {Pro}Coders  Full Stack Developer  Full-Stack Web Development
# ...            ...                   ...                         ...
# 1816    TechSwitch  Full Stack Developer        Software Development
# 1817    TechSwitch  Full Stack Developer        Software Development
# 1818    TechSwitch  Full Stack Developer        Software Development
# 1819    TechSwitch  Full Stack Developer        Software Development
# 1820    TechSwitch  Full Stack Developer        Software Development
#
#      course_skills course_locations
# 0              CSS   West Yorkshire  \
# 1             HTML   West Yorkshire
# ...

# %%
exploded_tracks.head(100)
# Out:
#    provider_name       provider_tracks                 course_name
# 0    {Pro}Coders  Full Stack Developer  Full-Stack Web Development  \
# 1    {Pro}Coders  Full Stack Developer  Full-Stack Web Development
# 2    {Pro}Coders  Full Stack Developer  Full-Stack Web Development
# 3    {Pro}Coders  Full Stack Developer  Full-Stack Web Development
# 4    {Pro}Coders  Full Stack Developer  Full-Stack Web Development
# ..           ...                   ...                         ...
# 95    Coders Lab  Full Stack Developer              Java Developer
# 96    Coders Lab          Data Science              Java Developer
# 97    Coders Lab   Front End Developer              Java Developer
# 98    Coders Lab  Full Stack Developer        JavaScript Developer
# 99    Coders Lab          Data Science        JavaScript Developer
#
#    course_skills                                   course_locations
# 0            CSS                                     West Yorkshire  \
# ...
